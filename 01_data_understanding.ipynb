# %%
import os

print(os.getcwd())
# Out:
# D:\UAE-Telecom-Churn-Analytics\notebooks

# %%
import pandas as pd

df = pd.read_csv(r"D:\UAE-Telecom-Churn-Analytics\data\raw\UAE_Telecom_Enhanced_Dataset.csv")

df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges        Contract  \
# 0           1   56  Female      68          147.58        Two year
# 1           2   69    Male      32           22.54  Month-to-month
# 2           3   46  Female      10           52.47        One year
# 3           4   32    Male      22          109.67  Month-to-month
# 4           5   60  Female      54          130.98  Month-to-month
#
#       PaymentMethod  TotalCharges Churn    Emirate Nationality_Group  \
# 0     Bank transfer      10052.03    No      Dubai    Filipino Expat
# 1      Mailed check        686.78    No   Fujairah   Pakistani Expat
# 2  Electronic check        537.88    No    Sharjah      Indian Expat
# 3      Mailed check       2390.04   Yes  Abu Dhabi   Pakistani Expat
# 4       Credit card       7081.28    No      Dubai      Indian Expat
#
#   5G_Subscription Premium_Customer_Tier  International_Roaming_Usage_GB  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CustomerID                      100000 non-null  int64
#  1   Age                             100000 non-null  int64
#  2   Gender                          100000 non-null  str
#  3   Tenure                          100000 non-null  int64
#  4   MonthlyCharges                  100000 non-null  float64
#  5   Contract                        100000 non-null  str
#  6   PaymentMethod                   100000 non-null  str
#  7   TotalCharges                    100000 non-null  float64
#  8   Churn                           100000 non-null  str
#  9   Emirate                         100000 non-null  str
#  10  Nationality_Group               100000 non-null  str
#  11  5G_Subscription                 100000 non-null  str
# ...

# %%
df.head(10)
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges        Contract  \
# 0           1   56  Female      68          147.58        Two year
# 1           2   69    Male      32           22.54  Month-to-month
# 2           3   46  Female      10           52.47        One year
# 3           4   32    Male      22          109.67  Month-to-month
# 4           5   60  Female      54          130.98  Month-to-month
# 5           6   25  Female      29          111.55  Month-to-month
# 6           7   78  Female      20           63.23        One year
# 7           8   38    Male      11           96.63  Month-to-month
# 8           9   56    Male      43           74.06  Month-to-month
# 9          10   75   Other      62          109.39        One year
#
#       PaymentMethod  TotalCharges Churn    Emirate Nationality_Group  \
# 0     Bank transfer      10052.03    No      Dubai    Filipino Expat
# 1      Mailed check        686.78    No   Fujairah   Pakistani Expat
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'MonthlyCharges', 'Contract',
#        'PaymentMethod', 'TotalCharges', 'Churn', 'Emirate',
#        'Nationality_Group', '5G_Subscription', 'Premium_Customer_Tier',
#        'International_Roaming_Usage_GB', 'Ramadan_Usage_Spike_Percentage',
#        'WhatsApp_Call_Dependency', 'Estimated_ARPU_AED',
#        'Likely_Churn_Reason'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# CustomerID                        0
# Age                               0
# Gender                            0
# Tenure                            0
# MonthlyCharges                    0
# Contract                          0
# PaymentMethod                     0
# TotalCharges                      0
# Churn                             0
# Emirate                           0
# Nationality_Group                 0
# 5G_Subscription                   0
# Premium_Customer_Tier             0
# International_Roaming_Usage_GB    0
# Ramadan_Usage_Spike_Percentage    0
# WhatsApp_Call_Dependency          0
# Estimated_ARPU_AED                0
# Likely_Churn_Reason               0
# dtype: int64

# %%
df.describe()
# Out:
#           CustomerID            Age         Tenure  MonthlyCharges  \
# count  100000.000000  100000.000000  100000.000000   100000.000000
# mean    50000.500000      49.027240      36.527090       79.974933
# std     28867.657797      18.177862      20.789552       40.491961
# min         1.000000      18.000000       1.000000       10.000000
# 25%     25000.750000      33.000000      18.000000       44.720000
# 50%     50000.500000      49.000000      37.000000       80.000000
# 75%     75000.250000      65.000000      54.000000      115.050000
# max    100000.000000      80.000000      72.000000      150.000000
#
#         TotalCharges  International_Roaming_Usage_GB  \
# count  100000.000000                   100000.000000
# mean     2926.140256                        6.972908
# std      2388.163672                        5.773156
# min      -118.430000                        0.000000
# 25%       963.667500                        3.350000
# ...

# %%
df.shape
# Out:
# (100000, 18)

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     66856
# Yes    33144
# Name: count, dtype: int64

# %%
df['Emirate'].value_counts()
# Out:
# Emirate
# Dubai             38039
# Abu Dhabi         26999
# Sharjah           15057
# Ajman              7061
# Ras Al Khaimah     5980
# Fujairah           3969
# Umm Al Quwain      2895
# Name: count, dtype: int64

# %%
df['MonthlyCharges'].mean()
# Out:
# np.float64(79.9749334)

# %%
df['Premium_Customer_Tier'].value_counts()
# Out:
# Premium_Customer_Tier
# Standard    59734
# Silver      25537
# Gold         9615
# Platinum     5114
# Name: count, dtype: int64

# %%
df['5G_Subscription'].value_counts()
# Out:
# 5G_Subscription
# Yes    54885
# No     45115
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['Churn'].value_counts().plot(kind='bar')

plt.title("Customer Churn Distribution")

plt.show()

# %%
df['Emirate'].value_counts().plot(kind='bar')

plt.title("Customers by Emirate")

plt.show()
