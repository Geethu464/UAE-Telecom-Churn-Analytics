# %%
import pandas as pd

df = pd.read_csv(r"D:\UAE-Telecom-Churn-Analytics\data\raw\UAE_Telecom_Enhanced_Dataset.csv")

df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges        Contract  \
# 0           1   56  Female      68          147.58        Two year
# 1           2   69    Male      32           22.54  Month-to-month
# 2           3   46  Female      10           52.47        One year
# 3           4   32    Male      22          109.67  Month-to-month
# 4           5   60  Female      54          130.98  Month-to-month
#
#       PaymentMethod  TotalCharges Churn    Emirate Nationality_Group  \
# 0     Bank transfer      10052.03    No      Dubai    Filipino Expat
# 1      Mailed check        686.78    No   Fujairah   Pakistani Expat
# 2  Electronic check        537.88    No    Sharjah      Indian Expat
# 3      Mailed check       2390.04   Yes  Abu Dhabi   Pakistani Expat
# 4       Credit card       7081.28    No      Dubai      Indian Expat
#
#   5G_Subscription Premium_Customer_Tier  International_Roaming_Usage_GB  \
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                        0
# Age                               0
# Gender                            0
# Tenure                            0
# MonthlyCharges                    0
# Contract                          0
# PaymentMethod                     0
# TotalCharges                      0
# Churn                             0
# Emirate                           0
# Nationality_Group                 0
# 5G_Subscription                   0
# Premium_Customer_Tier             0
# International_Roaming_Usage_GB    0
# Ramadan_Usage_Spike_Percentage    0
# WhatsApp_Call_Dependency          0
# Estimated_ARPU_AED                0
# Likely_Churn_Reason               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# CustomerID                          int64
# Age                                 int64
# Gender                                str
# Tenure                              int64
# MonthlyCharges                    float64
# Contract                              str
# PaymentMethod                         str
# TotalCharges                      float64
# Churn                                 str
# Emirate                               str
# Nationality_Group                     str
# 5G_Subscription                       str
# Premium_Customer_Tier                 str
# International_Roaming_Usage_GB    float64
# Ramadan_Usage_Spike_Percentage    float64
# WhatsApp_Call_Dependency              str
# Estimated_ARPU_AED                float64
# Likely_Churn_Reason                   str
# dtype: object

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# CustomerID                        0
# Age                               0
# Gender                            0
# Tenure                            0
# MonthlyCharges                    0
# Contract                          0
# PaymentMethod                     0
# TotalCharges                      0
# Churn                             0
# Emirate                           0
# Nationality_Group                 0
# 5G_Subscription                   0
# Premium_Customer_Tier             0
# International_Roaming_Usage_GB    0
# Ramadan_Usage_Spike_Percentage    0
# WhatsApp_Call_Dependency          0
# Estimated_ARPU_AED                0
# Likely_Churn_Reason               0
# dtype: int64

# %%
df['MonthlyCharges'].describe()
# Out:
# count    100000.000000
# mean         79.974933
# std          40.491961
# min          10.000000
# 25%          44.720000
# 50%          80.000000
# 75%         115.050000
# max         150.000000
# Name: MonthlyCharges, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.boxplot(df['MonthlyCharges'])

plt.title("Monthly Charges Outliers")

plt.show()

# %%
df['Churn'].unique()
# Out:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df.columns
df.columns = df.columns.str.strip()

# %%
df.to_csv(r"D:\UAE-Telecom-Churn-Analytics\data\processed\cleaned_uae_telecom_data.csv", index=False)

# %%
import os

os.listdir(r"D:\UAE-Telecom-Churn-Analytics\data\processed")
# Out:
# ['cleaned_uae_telecom_data.csv']
